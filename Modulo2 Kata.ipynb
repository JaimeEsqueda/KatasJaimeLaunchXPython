# %% [markdown]
# Modulo 2

# %% [markdown]
# Captura de pantalla de la consola para crear y activar el entorno virtual.

# %%
from IPython.display import Image
Image("C:/Users/chimi/OneDrive/Documents/Python/Screenshot 1 Kata2.png")

# %% [markdown]
# Captura de pantalla de la consola para instalar una biblioteca

# %%
from IPython.display import Image
Image("C:/Users/chimi/OneDrive/Documents/Python/Screenshot 2 Kata2.png")

# %% [markdown]
# Captura de pantalla para desactivar un entorno virtual

# %%
from IPython.display import Image
Image("C:/Users/chimi/OneDrive/Documents/Python/Screenshot 3 Kata2.png")
